# %%
schema = {
    "fields": [
        {
            "name": "UserId",
            "fieldType": "string",
            "comment": "",
            "validation_rule": ""
        },
        # {
        #     "name": "UserIdHD",
        #     "fieldType": "string",
        #     "comment": "",
        #     "validation_rule": ""
        # },
        {
            "name": "HomePhone",
            "fieldType": "string",
            "comment": "",
            "validation_rule": ""
        },
        {
            "name": "WorkPhone",
            "fieldType": [
                "string",
                "null"
            ],
            "comment": "",
            "validation_rule": ""
        },
        {
            "name": "Address",
            "fieldType": "object",
            "comment": "",
            "validation_rule": "",
            "properties": [
                {
                    "name": "HouseNo",
                    "fieldType": "string",
                    "comment": "",
                    "validation_rule": ""
                },
                {
                    "name": "Streetname",
                    "fieldType": "string",
                    "comment": "",
                    "validation_rule": ""
                },
                {
                    "name": "Ward",
                    "fieldType": "string",
                    "comment": "",
                    "validation_rule": ""
                },
                {
                    "name": "District",
                    "fieldType": "string",
                    "comment": "",
                    "validation_rule": ""
                },
                {
                    "name": "Province",
                    "fieldType": "string",
                    "comment": "",
                    "validation_rule": ""
                },
                {
                    "name": "Country",
                    "fieldType": "string",
                    "comment": "",
                    "validation_rule": ""
                }
            ]
        },
        {
            "name": "Firstname",
            "fieldType": "string",
            "comment": "",
            "validation_rule": ""
        },
        {
            "name": "Lastname",
            "fieldType": "string",
            "comment": "",
            "validation_rule": ""
        },
        {
            "name": "Gender",
            "fieldType": "string",
            "comment": "",
            "validation_rule": ""
        },
        {
            "name": "RegisterDate",
            "fieldType": "datetime",
            "comment": "",
            "validation_rule": ""
        },
        {
            "name": "Status",
            "fieldType": "string",
            "comment": "",
            "validation_rule": ""
        },
        {
            "name": "DataSource",
            "fieldType": "string",
            "comment": "",
            "validation_rule": ""
        },
        {
            "name": "Source",
            "fieldType": "string",
            "comment": "",
            "validation_rule": ""
        },
        {
            "name": "EventId",
            "fieldType": "string",
            "comment": "",
            "validation_rule": ""
        }
    ]
}

data = {
    "UserId": 202201439424,
    "HomePhone": "0912919543",
    "WorkPhone": None,
    "Address": {
        "HouseNo": "",
        "Streetname": "",
        "Ward": "ẤP HÒA CƯỜNG, Xã Minh Hoà",
        "District": "Huyện Dầu Tiếng",
        "Province": "Tỉnh Bình Dương",
        "Country": "Việt Nam"
    },
    "Firstname": "TRẦN VĂN ",
    "Lastname": "TÙNG",
    "Gender": "Male",
    "RegisterDate": "2022-01-01T00:00:00.00Z",
    "Status": "True",
    "DataSource": "VTVHyundai",
    "Source": "VTVHyundai",
    "EventId": "VTVHyundai_IngestProfile_202201439424",
}

# %%
import airflow.dags.schema_validator as schema_validator
def build_path(path, key):
    return key if len(path) == 0 else path + '.' + key
def get_default_value(m_key):
    # Model field is an array of objects
    # case1:     foo: [{bar: ['string', 'value']}]
    if type(m_key) is list and type(m_key[0]) is dict:
        return []

    # Model field is an object
    # case2:     foo: {bar: ['string', 'value']}
    if type(m_key) is dict:
        res = {}
        for key in m_key.keys():
            res[key] = get_default_value(m_key[key])
        return res

    # case3:     foo: ['string', 'value']
    return m_key[1]

# %%
schema = {
    "Fields": [
      {"Name": "UserId", "FieldType": "string", "Validation": "String,MustHave", "Comment": "id của user trong hệ thống, phải là kiểu string" },
      {"Name": "HomePhone", "FieldType": "string", "Comment": "Nếu không có thì để trống" },
      {"Name": "WorkPhone", "FieldType": ["string", "null"], "Comment": "Nếu không có thì để trống" },
      {"Name": "AddrHouseNo", "FieldType": "string", "Comment": "Số nhà" },
      {"Name": "AddrStreetName", "FieldType": "string", "Comment": "Tên đường" },
      {"Name": "AddrWard", "FieldType": "string", "Comment": "Phường / Xã" },
      {"Name": "AddrDistrict", "FieldType": "string", "Comment": "Quận / Huyện / Thành Phố trực thuộc tỉnh" },
      {"Name": "AddrProvince", "FieldType": "string", "Comment": "Tỉnh / Thành phố trực thuộc TW" },
      {"Name": "AddrCountry", "FieldType": "string", "Validation": "Iso Country Code", "Comment": "Tên nước - ISO Country Code - E.g. VN" },
      {"Name": "Firstname", "FieldType": "string", "Comment": "Tên" },
      {"Name": "Lastname", "FieldType": "string", "Comment": "Họ và chữ lót" },
      {"Name": "Gender", "FieldType": "string", "Comment": "Giới tính, tiếng anh, để khỏi bị nhầm lẫn", "Validation": "Male/Female/Other" },
      {"Name": "RegisterDate", "FieldType": "string", "Comment": "Ngày đăng ký vào hệ thống" },
      {"Name": "DataSource", "FieldType": "string", "Comment": "DataProviderName" },
      {"Name": "MaritalStatus", "FieldType": "string", "Comment": "Tình trạng hôn nhân", "Validation": "Single/Married" }
    ]
  }

# %%
# errors = schema_validator.validate_v2(schema,data)\
schema_dict = {}
for field in schema["fields"]:
    if field["fieldType"] == "object":
        schema_dict[field["name"]] = {}
        for property in field["properties"]:
            schema_dict[field["name"]][property["name"]] = property["fieldType"]
    else:
        schema_dict[field["name"]] = field["fieldType"]
path = ""
result = []
print(schema_dict)

# %%
for field in data:
    if field not in list_field_name:
        fullpath = build_path(path, field)
        field_type = type(data[field]).__name__
        error_response = {
            'msg': '[+] Extra field: "{}" having type: "{}"'.format(fullpath, field_type),
            'type': 'extra_field',
            'path': fullpath,
            'field_type': field_type
        }
        result.append(error_response)

# %%
print(list_field_name)
print(result)

# %%
type_field = schema["fields"][]
for key in list_field_name:
    if key not in data:
        fullpath = build_path(path, key)
        error_response = {
            'msg': '[-] Missing field: "{}"'.format(fullpath),
            'type': 'missing_field',
            'path': fullpath,
            'default_value': get_default_value([key])
        }
        result.append(error_response)
        continue

# %%
schema = {
    "UserId" : "int",
    "HomePhone" : "string",
    "WorkPhone" : ["string", "null"],
    "Address" : {
        "HouseNo": "string",
        "Streetname": "string",
        "Ward": "string",
        "District": "string",
        "Province": "string",
        "Country": "string"
    },
    "Firstname" : "string",
    "Lastname" : "string",
    "Gender" : "string",
    "RegisterDate" : "datetime",
    "Status" : "string",
    "DataSource" : "string",
    "Source" : "string",
    "EventId" : "string"
}
data = {
    "UserId": 202201439424,
    "HomePhone": "0912919543",
    "WorkPhone": None,
    "Address": {
        "HouseNo": "",
        "Streetname": "",
        "Ward": "ẤP HÒA CƯỜNG, Xã Minh Hoà",
        "District": "Huyện Dầu Tiếng",
        "Province": "Tỉnh Bình Dương",
        "Country": "Việt Nam"
    },
    "Firstname": "TRẦN VĂN ",
    "Lastname": "TÙNG",
    "Gender": "Male",
    "RegisterDate": "2022-01-01T00:00:00.00Z",
    "Status": "True",
    "DataSource": "VTVHyundai",
    "Source": "VTVHyundai",
    "EventId": "VTVHyundai_IngestProfile_202201439424"
}
a = schema_validator.validate(schema,data)

# %%
a

# %%
from enum import Enum
import os
class S3BucketConfig(Enum):
    QC_BUCKET = 'teracdp-data-quality'
    QC_ACCEPT_PATH = 'accept'
    QC_REJECT_PATH = 'reject'
print(S3BucketConfig.QC_BUCKET.value)
print(os.path.join(*[S3BucketConfig.QC_ACCEPT_PATH.value, "data_source", "uploaded_date", "event_name", "filename"]))

# %%
import boto3
from boto3.dynamodb.conditions import Attr, And, Key
from functools import reduce
DYNAMODB_DATA_SCHEMA_TABLE = 'SchemaRegistry'
DYNAMODB_DATA_PROVIDER_SCHEMA = 'DataProviderSchema'
DYNAMODB_DATA_QUALITY_CONTROL_LOG = 'QualityControlLog'
dynamodb_resource = boto3.resource(
        'dynamodb',
        aws_access_key_id="AKIAZQSLELDPHSPH6LFK",
        aws_secret_access_key="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",
        region_name="ap-southeast-1",
    )
table = dynamodb_resource.Table(DYNAMODB_DATA_PROVIDER_SCHEMA) 
attribs = {'DataProvider':"VTVHuyndai", 'EventName':"IngestProfile"}
response = table.scan(
    FilterExpression=(
        reduce(And, [Key(k).eq(v) for k, v in attribs.items()])
    )
)
rows = response.get('Items')

# %%
print(rows)

# %%
from tera_etl import quality_control as qc
schema = {
    "UserId" : "int",
    "HomePhone" : "string",
    "WorkPhone" : ["string", "null"],
    "Address" : {
        "HouseNo": "string",
        "Streetname": "string",
        "Ward": "string",
        "District": "string",
        "Province": "string",
        "Country": "string"
    },
    "Firstname" : "string",
    "Lastname" : "string",
    "Gender" : "string",
    "RegisterDate" : "datetime",
    "Status" : "string",
    "DataSource" : "string",
    "Source" : "string",
    "EventId" : "string"
}
data = {
    "UserId": 202201439424,
    "HomePhone": "0912919543",
    "WorkPhone": None,""
    "Address": {
        "HouseNo": "",
        "Streetname": "",
        "Ward": "ẤP HÒA CƯỜNG, Xã Minh Hoà",
        "District": "Huyện Dầu Tiếng",
        "Province": "Tỉnh Bình Dương",
        "Country": "Việt Nam"
    },
    "Firstname": "TRẦN VĂN ",
    "Lastname": "TÙNG",
    "Gender": "Male",
    "RegisterDate": "2022-01-01T00:00:00.00Z",
    "Status": "True",
    "DataSource": "VTVHyundai",
    "Source": "VTVHyundai",
    "EventId": "VTVHyundai_IngestProfile_202201439424"
}
qc_type = qc.classify_data(data_chunk=data, schema=schema)
# Out:
# data_chunk
# schema
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 44
#       2 schema = {
#       3     "UserId" : "int",
#       4     "HomePhone" : "string",
#    (...)
#      21     "EventId" : "string"
#      22 }
#      23 data = {
#      24     "UserId": 202201439424,
#      25     "HomePhone": "0912919543",
#    (...)
#      42     "EventId": "VTVHyundai_IngestProfile_202201439424"
#      43 }
# ---> 44 qc_type = qc.classify_data(data_chunk=data, schema=schema)
#
# File ~/Documents/tera/gitTera/tera-cdp-system/tera-etl/tera_etl/quality_control.py:13, in classify_data(**kwargs)
#      11 def classify_data(**kwargs) -> QualityControlResult:
#      12     data_chunk, schema = kwargs
# ---> 13     return QualityControlResult.ACCEPTED if __is_accepted(data_chunk, schema) else QualityControlResult.REJECTED
#
# File ~/Documents/tera/gitTera/tera-cdp-system/tera-etl/tera_etl/quality_control.py:17, in __is_accepted(chunk, schema)
#      16 def __is_accepted(chunk, schema):
# ---> 17     if not __has_valid_schema(chunk, schema):
#      18         return False
#      19     return True
#
# File ~/Documents/tera/gitTera/tera-cdp-system/tera-etl/tera_etl/quality_control.py:27, in __has_valid_schema(data, schema)
#      25 print(data)
#      26 print(schema)
# ---> 27 return True if not validate(schema=schema, data=data) else False
#
# File ~/Documents/tera/gitTera/tera-cdp-system/tera-etl/tera_etl/validations/schema_validation.py:75, in validate(schema, data, path)
#      69 # Verify that passed document is a dictionary
#      70 # if type(data) is not dict:
#      71 #     raise Exception('Document passed to "validate" function must be a dictionary')
#      72
#      73 # Check for extra fields in mongo doc
#      74 for field in data:
# ---> 75     if field not in schema.keys():
#      76         fullpath = build_path(path, field)
#      77         field_type = type(data[field]).__name__
#
# AttributeError: 'str' object has no attribute 'keys'

# %%
def classify_data(data_chunk,schema, **kwargs):
    print(kwargs)
    print(schema)
    print(data_chunk)

classify_data(data_chunk=data, schema=schema)
# Out:
# {}
# {'UserId': 'int', 'HomePhone': 'string', 'WorkPhone': ['string', 'null'], 'Address': {'HouseNo': 'string', 'Streetname': 'string', 'Ward': 'string', 'District': 'string', 'Province': 'string', 'Country': 'string'}, 'Firstname': 'string', 'Lastname': 'string', 'Gender': 'string', 'RegisterDate': 'datetime', 'Status': 'string', 'DataSource': 'string', 'Source': 'string', 'EventId': 'string'}
# {'UserId': 202201439424, 'HomePhone': '0912919543', 'WorkPhone': None, 'Address': {'HouseNo': '', 'Streetname': '', 'Ward': 'ẤP HÒA CƯỜNG, Xã Minh Hoà', 'District': 'Huyện Dầu Tiếng', 'Province': 'Tỉnh Bình Dương', 'Country': 'Việt Nam'}, 'Firstname': 'TRẦN VĂN ', 'Lastname': 'TÙNG', 'Gender': 'Male', 'RegisterDate': '2022-01-01T00:00:00.00Z', 'Status': 'True', 'DataSource': 'VTVHyundai', 'Source': 'VTVHyundai', 'EventId': 'VTVHyundai_IngestProfile_202201439424'}
